# %% [markdown]
# <a href="https://colab.research.google.com/github/LiYingjie-21/WELLCOME-shop-information-analysis/blob/main/WELLCOME_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_excel("/content/LiYingjie_25D027_WELLCOME_Store_Information.xlsx")
LiYingjie_25D027_WELLCOME_DF=df
df
# Out:
#               Store Name                                            Address  \
# 0        Victoria Centre               No.15 Watson Road, North Point, H.K.
# 1         Mercury Street               28 Mercury Street, North Point, H.K.
# 2   Fortress Metro Tower                              238 King’s Road, H.K.
# 3            City Garden  7-14 , City Garden , No. 233 Electrial Road , ...
# 4            North Point                 338 King's Road, North Point, H.K.
# 5              Metropole         No. 416-426 King's Road, North Point, H.K.
# 6           Island Lodge               61 & 63 Marble Rd, North Point, H.K.
# 7                Fitfort                 560 King's Road, North Point, H.K.
# 8        Healthy Village           188 Tsat Tsz Mui Road, North Point, H.K.
# 9              Gold Luck              989-992 King's Road, Quarry Bay, H.K.
# 10             Park Vale              No.1060 King's Road, Quarry Bay, H.K.
# ...

# %%
LiYingjie_25D027_NP=np.array(LiYingjie_25D027_WELLCOME_DF["Store Name"])
print(LiYingjie_25D027_NP)
# Out:
# ['Victoria Centre' 'Mercury Street' 'Fortress Metro Tower' 'City Garden'
#  'North Point' 'Metropole' 'Island Lodge' 'Fitfort' 'Healthy Village'
#  'Gold Luck' 'Park Vale' 'Kornhill' 'Tai Shan' 'Upper East'
#  'Tai On Building' 'Lei King Wan' 'Yiu Tung' 'Sun Sing' 'Harmony Place'
#  'Aldrich Garden' 'Perfect Mount' 'Fung Wah' 'Hing Wah' 'Ko Way' 'Winner'
#  'Wan Tsui' 'Siu Sai Wan']

# %%
LiYingjie_25D027_dict=dict(zip(
        LiYingjie_25D027_WELLCOME_DF["Store Name"],
        LiYingjie_25D027_WELLCOME_DF["Operating_Hours"]
))
print(LiYingjie_25D027_dict)
# Out:
# {'Victoria Centre': '08:00-22:00', 'Mercury Street': '08:00-22:00', 'Fortress Metro Tower': '08:00-23:00', 'City Garden': '08:30-22:00', 'North Point': '08:00-22:00', 'Metropole': '08:00-23:00', 'Island Lodge': '08:30-22:00', 'Fitfort': '08:30-22:01', 'Healthy Village': '08:00-22:00', 'Gold Luck': '08:00-23:00', 'Park Vale': '08:00-23:00', 'Kornhill': '08:00-21:00', 'Tai Shan': '08:00-22:00', 'Upper East': '08:30-21:30', 'Tai On Building': '08:00-22:00', 'Lei King Wan': '08:00-21:00', 'Yiu Tung': '08:00-21:30', 'Sun Sing': '08:30-22:00', 'Harmony Place': '08:30-21:00', 'Aldrich Garden': '08:00-21:30', 'Perfect Mount': '08:00-23:00', 'Fung Wah': '08:00-20:30', 'Hing Wah': '09:00-20:30', 'Ko Way': '08:30-21:30', 'Winner': '09:00-20:00', 'Wan Tsui': '08:00-22:00', 'Siu Sai Wan': '08:00-23:00'}

# %%
open_24h = LiYingjie_25D027_WELLCOME_DF[LiYingjie_25D027_WELLCOME_DF["Operating_Hours"].str.contains("24 Hours", na=False)]
print(open_24h)
# Out:
# Empty DataFrame
# Columns: [Store Name, Address, Floor, Number, Operating_Hours, Building_Name]
# Index: []

# %%
LiYingjie_25D027_WELLCOME_DF.iloc[:,[0,2,4]]
# Out:
#               Store Name                                Floor Operating_Hours
# 0        Victoria Centre                                  G/F     08:00-22:00
# 1         Mercury Street                                  G/F     08:00-22:00
# 2   Fortress Metro Tower                                  G/F     08:00-23:00
# 3            City Garden                   30-33 Ground Floor     08:30-22:00
# 4            North Point                                  G/F     08:00-22:00
# 5              Metropole                  Portion of Basement     08:00-23:00
# 6           Island Lodge                                 G/F      08:30-22:00
# 7                Fitfort                                 G/F      08:30-22:01
# 8        Healthy Village                      (Portion), UG/F     08:00-22:00
# 9              Gold Luck                   Upper Ground Floor     08:00-23:00
# 10             Park Vale                    Upper Grond Floor     08:00-23:00
# ...

# %%
c.columns
# Out:
# Index(['Store Name', 'Address', 'Floor', 'Number', 'Operating_Hours',
#        'Building_Name'],
#       dtype='object')

# %%
LiYingjie_25D027_WELLCOME_DF["Area"]="Hong Kong Island"
print(LiYingjie_25D027_WELLCOME_DF)
# Out:
#               Store Name                                            Address  \
# 0        Victoria Centre               No.15 Watson Road, North Point, H.K.
# 1         Mercury Street               28 Mercury Street, North Point, H.K.
# 2   Fortress Metro Tower                              238 King’s Road, H.K.
# 3            City Garden  7-14 , City Garden , No. 233 Electrial Road , ...
# 4            North Point                 338 King's Road, North Point, H.K.
# 5              Metropole         No. 416-426 King's Road, North Point, H.K.
# 6           Island Lodge               61 & 63 Marble Rd, North Point, H.K.
# 7                Fitfort                 560 King's Road, North Point, H.K.
# 8        Healthy Village           188 Tsat Tsz Mui Road, North Point, H.K.
# 9              Gold Luck              989-992 King's Road, Quarry Bay, H.K.
# 10             Park Vale              No.1060 King's Road, Quarry Bay, H.K.
# ...

# %%
LiYingjie_25D027_WELLCOME_DF.to_csv("LiYingjie_25D027_abc.csv")
